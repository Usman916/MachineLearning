# %%
# !pip install pandas

# %%
import os

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/MyDrive/Praktikum/Praktikum1/Data/'
os.listdir(path)
# Out:
# ['day.csv', 'hour.csv']

# %%
df = pd.read_csv ("/content/drive/MyDrive/Praktikum/Praktikum1/Data/hour.csv")
df
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 0            1  2011-01-01       1   0     1   0        0        6
# 1            2  2011-01-01       1   0     1   1        0        6
# 2            3  2011-01-01       1   0     1   2        0        6
# 3            4  2011-01-01       1   0     1   3        0        6
# 4            5  2011-01-01       1   0     1   4        0        6
# ...        ...         ...     ...  ..   ...  ..      ...      ...
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 0               0           1  0.24  0.2879  0.81     0.0000       3
# ...

# %%
# Membuat dataframe baru (df1) dengan kolom yang dipilih
df1 = df[['instant', 'dteday', 'season', 'temp', 'hum', 'windspeed']]
df1
# Out:
#        instant      dteday  season  temp   hum  windspeed
# 0            1  2011-01-01       1  0.24  0.81     0.0000
# 1            2  2011-01-01       1  0.22  0.80     0.0000
# 2            3  2011-01-01       1  0.22  0.80     0.0000
# 3            4  2011-01-01       1  0.24  0.75     0.0000
# 4            5  2011-01-01       1  0.24  0.75     0.0000
# ...        ...         ...     ...   ...   ...        ...
# 17374    17375  2012-12-31       1  0.26  0.60     0.1642
# 17375    17376  2012-12-31       1  0.26  0.60     0.1642
# 17376    17377  2012-12-31       1  0.26  0.60     0.1642
# 17377    17378  2012-12-31       1  0.26  0.56     0.1343
# 17378    17379  2012-12-31       1  0.26  0.65     0.1343
#
# [17379 rows x 6 columns]

# %%
df1.to_csv('/content/drive/MyDrive/Praktikum/Praktikum1/Data/latihan01.csv', index=False)


print("\nDataFrame berhasil disimpan ke 'latihan01.csv'")
# Out:
# DataFrame berhasil disimpan ke 'latihan01.csv'
